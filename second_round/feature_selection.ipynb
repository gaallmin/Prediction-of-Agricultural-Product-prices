# %%
import pandas as pd
import numpy as np

train_1 = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/train_1.csv')
train_2 = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/train_2.csv')

meta_weather = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/meta/TRAIN_기상_2018-2022.csv')
meta_production = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/meta/TRAIN_생산정보_2018_2022.csv')
meta_nationwide_market = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/meta/TRAIN_경락정보_전국도매_2018-2022.csv')
meta_retail = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/meta/TRAIN_소매_2018-2022.csv')
meta_wholesale = pd.read_csv('A:/UNI/website/Prediction-of-Agricultural-Product-prices/second_round/data/train/meta/TRAIN_중도매_2018-2022.csv')

print("train_1 head:")
print(train_1.head())
print("\ntrain_2 head:")
print(train_2.head())
print("\nweather head:")
print(meta_weather.head())
print("\nproduction head:")
print(meta_production.head())
print("\nnationwide_market head:")
print(meta_nationwide_market.head())
print("\nretail head:")
print(meta_retail.head())
print("\nwholesale head:")
print(meta_wholesale.head())
# Out:
# train_1 head:
#   YYYYMMSOON  가락시장 품목코드(5자리) 품목(품종)명    거래단위 등급(특 5% 상 35% 중 40% 하 20%)  \
# 0   201801상순           21100      배추  10키로망대                          상
# 1   201801중순           21100      배추  10키로망대                          상
# 2   201801하순           21100      배추  10키로망대                          상
# 3   201802상순           21100      배추  10키로망대                          상
# 4   201802중순           21100      배추  10키로망대                          상
#
#        평균가격(원)  전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0  5419.857143               5293.333333                 5242.125000
# 1  5319.333333               5419.857143                 5553.222222
# 2  6734.777778               5319.333333                 5293.333333
# 3  8942.222222               6734.777778                 5419.857143
# 4  7247.166667               8942.222222                 5319.333333
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON
# 0               9213.428571                  6071.726190
# 1               9083.777778                  5938.143519
# 2               8292.166667                  6245.351852
# 3               9323.000000                  6413.720238
# 4               9243.250000                  7099.146825
#
# train_2 head:
#   YYYYMMSOON  품목코드   품목명  품종코드  품종명 등급명 유통단계별 무게   유통단계별 단위    평균가격(원)  \
# 0   201801상순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 1   201801중순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 2   201801하순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 3   201802상순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 4   201802중순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
#
#    전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0                       0.0                    643000.0
# 1                       0.0                    620000.0
# 2                       0.0                    590833.0
# 3                       0.0                    590000.0
# 4                       0.0                    590000.0
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON
# 0                  286429.0                381666.666667
# 1                  285000.0                380809.666667
# 2                  285000.0                380000.000000
# 3                  280000.0                380000.000000
# 4                  280000.0                376666.666667
#
# weather head:
#   YYYYMMSOON 지역 이름 주산지 품목명 주산지 품종명  순 평균상대습도    순 평균기온    순 평균풍속  순 최고기온  \
# 0   201801상순     A      감자       봄  0.616162  0.166667  0.142857   0.075
# 1   201801상순     B      감자       봄  0.737374  0.214286  0.142857   0.100
# 2   201801상순     C      감자     고랭지  0.535354  0.142857  0.142857   0.075
# 3   201801상순     D      감자      가을  0.656566  0.380952  0.571429   0.275
# 4   201801상순     E     건고추       -  0.646465  0.166667  0.142857   0.075
#
#    순 최저상대습도    순 최저기온     순 강수량  순 누적 일조시간 특보 코드   특보 명  특보 발효 순통계 개수
# 0  0.224719  0.235294  0.000000   0.488550    C2  한파주의보      0.090909
# 1  0.415730  0.274510  0.008054   0.000000    S2  대설주의보      0.090909
# 2  0.157303  0.215686  0.001342   0.480916    C2  한파주의보      0.090909
# 3  0.382022  0.470588  0.021477   0.160305    W2  강풍주의보      0.090909
# 4  0.247191  0.137255  0.008054   0.000000    S2  대설주의보      0.090909
#
# production head:
#      년도 품목명  재배면적(ha)   생산량(톤)
# 0  2018  배추     31143  2391946
# 1  2018  상추      3773    93543
# 2  2019  배추     25837  1859705
# 3  2019  상추      3629    95582
# 4  2020  배추     30949  2242640
#
# nationwide_market head:
#   YYYYMMSOON    시장코드      시장명  품목코드 품목명   품종코드   품종명   총반입량(kg)    총거래금액(원)  \
# 0   201801상순  100000  *전국도매시장   501  감자  50124   깐감자       20.0       86520
# 1   201801상순  100000  *전국도매시장   501  감자  50121  돼지감자    12380.0    11650810
# 2   201801상순  100000  *전국도매시장   501  감자  50110  자주감자      240.0      158400
# 3   201801상순  100000  *전국도매시장   501  감자  50111  가을감자       10.0       37500
# 4   201801상순  100000  *전국도매시장   501  감자  50199  기타감자  1367301.3  2403199462
#
#      평균가(원/kg)  ...  저가(20%) 평균가    중간가(원/kg)  최저가(원/kg)     최고가(원/kg)  경매 건수  \
# 0  4326.000000  ...  4326.000000  4326.000000     4326.0   4326.000000      1
# 1   941.099354  ...   545.105717  1010.000000      200.0   3000.000000    117
# 2   660.000000  ...   500.000000   550.000000      500.0   1000.000000      7
# 3  3750.000000  ...  3700.000000  3750.000000     3700.0   3800.000000      2
# 4  1757.622451  ...   955.289668  1360.453431        0.0  10581.081081    872
#
#    전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0                  0.000000                 4009.000000
# 1              11213.358450                 9174.196723
# 2              12553.279352                12612.216445
# 3              24929.463415                40365.081269
# 4              30806.779529                27661.150770
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON    연도
# 0                  0.000000                     0.000000  2018
# 1               8167.895632                     0.000000  2018
# 2              24990.324897                 18483.961304  2018
# 3                  0.000000                     0.000000  2018
# 4              23741.953223                 19340.121989  2018
#
# [5 rows x 22 columns]
#
# retail head:
#   YYYYMMSOON  품목코드   품목명  품종코드   품종명 등급명 유통단계별 무게   유통단계별 단위   평균가격(원)  \
# 0   201801상순    152   감자      2  대지마  중품         g        100      516
# 1   201801상순    152   감자      1   수미  중품         g        100      265
# 2   201801상순    152   감자      1   수미  상품         g        100      331
# 3   201801상순    152   감자      2  대지마  상품         g        100      603
# 4   201801상순    241  건고추      2   양건  상품         g        600    20674
#
#    전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0                         0                           0
# 1                         0                         250
# 2                         0                         374
# 3                         0                           0
# 4                         0                       20704
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON
# 0                         0                     0.000000
# 1                       210                   194.666667
# 2                       321                   266.666667
# 3                       773                     0.000000
# 4                     11409                 12557.333333
#
# wholesale head:
#   YYYYMMSOON  품목코드   품목명  품종코드  품종명 등급명 유통단계별 무게   유통단계별 단위   평균가격(원)  \
# 0   201801상순    152   감자      1  수미  중품        kg         20    43829
# 1   201801상순    152   감자      1  수미  상품        kg         20    49029
# 2   201801상순    241  건고추      2  양건  상품        kg         30   715000
# 3   201801상순    241  건고추      2  양건  중품        kg         30   670000
# 4   201801상순    241  건고추      0  화건  중품        kg         30   545000
#
#    전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0                         0                       41120
# 1                         0                       46320
# 2                         0                      768000
# 3                         0                      723000
# 4                         0                      593000
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON
# 0                     29200                 22049.000000
# 1                     33200                 26164.333333
# 2                    366429                465476.333333
# 3                    316429                415476.333333
# 4                    241429                338333.333333

# %%
# diff year, mm, soon
def datetime_cov(df):
    df['year'] = df['YYYYMMSOON'].str.slice(0,4).astype(int)
    df['month'] = df['YYYYMMSOON'].str.slice(4,6).astype(int)
    df['soon'] = df['YYYYMMSOON'].str.slice(6)

    # mapping 하중상
    period_mapping = {'상순': 1, '중순': 11, '하순': 21}
    df['day'] = df['soon'].map(period_mapping)

    df = df.dropna(subset=['day'])
    df['date'] = pd.to_datetime(df[['year', 'month', 'day']])
    
    return df

train_1 = datetime_cov(train_1)
train_2 = datetime_cov(train_2)
meta_weather = datetime_cov(meta_weather)
meta_retail = datetime_cov(meta_retail)
# meta_production = datetime_cov(meta_production) : doesnt have YYYYYMMSOON
meta_wholesale = datetime_cov(meta_wholesale)



print("train_1 head:")
print(train_1.head())
print("\ntrain_2 head:")
print(train_2.head())
print("\nweather head:")
print(meta_weather.head())
# Out:
# train_1 head:
#   YYYYMMSOON  가락시장 품목코드(5자리) 품목(품종)명    거래단위 등급(특 5% 상 35% 중 40% 하 20%)  \
# 0   201801상순           21100      배추  10키로망대                          상
# 1   201801중순           21100      배추  10키로망대                          상
# 2   201801하순           21100      배추  10키로망대                          상
# 3   201802상순           21100      배추  10키로망대                          상
# 4   201802중순           21100      배추  10키로망대                          상
#
#        평균가격(원)  전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0  5419.857143               5293.333333                 5242.125000
# 1  5319.333333               5419.857143                 5553.222222
# 2  6734.777778               5319.333333                 5293.333333
# 3  8942.222222               6734.777778                 5419.857143
# 4  7247.166667               8942.222222                 5319.333333
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON  year  month soon  \
# 0               9213.428571                  6071.726190  2018      1   상순
# 1               9083.777778                  5938.143519  2018      1   중순
# 2               8292.166667                  6245.351852  2018      1   하순
# 3               9323.000000                  6413.720238  2018      2   상순
# 4               9243.250000                  7099.146825  2018      2   중순
#
#    day       date
# 0    1 2018-01-01
# 1   11 2018-01-11
# 2   21 2018-01-21
# 3    1 2018-02-01
# 4   11 2018-02-11
#
# train_2 head:
#   YYYYMMSOON  품목코드   품목명  품종코드  품종명 등급명 유통단계별 무게   유통단계별 단위    평균가격(원)  \
# 0   201801상순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 1   201801중순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 2   201801하순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 3   201802상순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
# 4   201802중순  241.0  건고추    0.0  화건  상품        kg       30.0  590000.0
#
#    전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0                       0.0                    643000.0
# 1                       0.0                    620000.0
# 2                       0.0                    590833.0
# 3                       0.0                    590000.0
# 4                       0.0                    590000.0
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON  year  month soon  \
# 0                  286429.0                381666.666667  2018      1   상순
# 1                  285000.0                380809.666667  2018      1   중순
# 2                  285000.0                380000.000000  2018      1   하순
# 3                  280000.0                380000.000000  2018      2   상순
# 4                  280000.0                376666.666667  2018      2   중순
#
#    day       date
# 0    1 2018-01-01
# 1   11 2018-01-11
# 2   21 2018-01-21
# 3    1 2018-02-01
# 4   11 2018-02-11
#
# weather head:
#   YYYYMMSOON 지역 이름 주산지 품목명 주산지 품종명  순 평균상대습도    순 평균기온    순 평균풍속  순 최고기온  \
# 0   201801상순     A      감자       봄  0.616162  0.166667  0.142857   0.075
# 1   201801상순     B      감자       봄  0.737374  0.214286  0.142857   0.100
# 2   201801상순     C      감자     고랭지  0.535354  0.142857  0.142857   0.075
# 3   201801상순     D      감자      가을  0.656566  0.380952  0.571429   0.275
# 4   201801상순     E     건고추       -  0.646465  0.166667  0.142857   0.075
#
#    순 최저상대습도    순 최저기온     순 강수량  순 누적 일조시간 특보 코드   특보 명  특보 발효 순통계 개수  year  \
# 0  0.224719  0.235294  0.000000   0.488550    C2  한파주의보      0.090909  2018
# 1  0.415730  0.274510  0.008054   0.000000    S2  대설주의보      0.090909  2018
# 2  0.157303  0.215686  0.001342   0.480916    C2  한파주의보      0.090909  2018
# 3  0.382022  0.470588  0.021477   0.160305    W2  강풍주의보      0.090909  2018
# 4  0.247191  0.137255  0.008054   0.000000    S2  대설주의보      0.090909  2018
#
#    month soon  day       date
# 0      1   상순    1 2018-01-01
# 1      1   상순    1 2018-01-01
# 2      1   상순    1 2018-01-01
# 3      1   상순    1 2018-01-01
# 4      1   상순    1 2018-01-01

# %%
meta_production.head()
# Out:
#      년도 품목명  재배면적(ha)   생산량(톤)
# 0  2018  배추     31143  2391946
# 1  2018  상추      3773    93543
# 2  2019  배추     25837  1859705
# 3  2019  상추      3629    95582
# 4  2020  배추     30949  2242640

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 마이너스 폰트 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

train_1['품목-품종'] = train_1['품목(품종)명']
train_2['품목-품종'] = train_2['품목명'] + '-' + train_2['품종명']


def plot_data_by_product(df, date_col, product_col, value_col):
    product_varieties = df[product_col].unique()
    for pv in product_varieties:
        subset = df[df[product_col] == pv]
        plt.figure(figsize=(10, 6))
        plt.plot(subset[date_col], subset[value_col], marker='o')
        plt.title(f'{pv} - {value_col} Over Time')
        plt.xlabel('Date')
        plt.ylabel(value_col)
        plt.xticks(rotation=45)
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# Plot data for train_1
plot_data_by_product(train_1, 'date', '품목-품종', '평균가격(원)')

# Plot data for train_2
plot_data_by_product(train_2, 'date', '품목-품종', '평균가격(원)')

# %%
# 계절 특보와 상관 관계
train_1['품목명'] = train_1['품목(품종)명'] 
weather_cols = ['date', '주산지 품목명', '주산지 품종명', '지역 이름', '특보 명']
weather_data = meta_weather[weather_cols].drop_duplicates()
weather_data.rename(columns={'주산지 품목명': '품목명', '주산지 품종명': '품종명'}, inplace=True)

train_1_merged = pd.merge(train_1, weather_data, on=['date', '품목명'], how='left')
train_2_merged = pd.merge(train_2, weather_data, on=['date', '품목명'], how='left')

# Add flag for presence of '특보 명'
train_1_merged['특보명 존재'] = train_1_merged['특보 명'].notnull().astype(int)
train_2_merged['특보명 존재'] = train_2_merged['특보 명'].notnull().astype(int)


def plot_data_with_weather_flag(df, date_col, product_col, value_col, weather_flag_col):
    product_varieties = df[product_col].unique()
    for pv in product_varieties:
        subset = df[df[product_col] == pv]
        plt.figure(figsize=(12, 6))
        plt.plot(subset[date_col], subset[value_col], marker='o', label='Price')
        
        # Mark points where '특보명' exists
        weather_dates = subset[subset[weather_flag_col] == 1][date_col]
        weather_prices = subset[subset[weather_flag_col] == 1][value_col]
        plt.scatter(weather_dates, weather_prices, color='red', label='Weather Warning', zorder=5)
        
        plt.title(f'{pv} - {value_col} Over Time with Weather Warnings')
        plt.xlabel('Date')
        plt.ylabel(value_col)
        plt.xticks(rotation=45)
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()


plot_data_with_weather_flag(train_1_merged, 'date', '품목-품종', '평균가격(원)', '특보명 존재')
plot_data_with_weather_flag(train_2_merged, 'date', '품목-품종', '평균가격(원)', '특보명 존재')

# %% [markdown]
# data-adding features

# %%
print("train_1 head:")
print(train_1.head(0))
print("\ntrain_2 head:")
print(train_2.head(0))
print("\nweather head:")
print(meta_weather.head(0))
print("\nproduction head:")
print(meta_production.head(0))
print("\nnationwide_market head:")
print(meta_nationwide_market.head(0))
print("\nretail head:")
print(meta_retail.head(0))
print("\nwholesale head:")
print(meta_wholesale.head(0))
# Out:
# train_1 head:
# Empty DataFrame
# Columns: [YYYYMMSOON, 가락시장 품목코드(5자리), 품목(품종)명, 거래단위, 등급(특 5% 상 35% 중 40% 하 20%), 평균가격(원), 전순 평균가격(원) PreVious SOON, 전달 평균가격(원) PreVious MMonth, 전년 평균가격(원) PreVious YeaR, 평년 평균가격(원) Common Year SOON, year, month, soon, day, date, 품목-품종, 품목명]
# Index: []
#
# train_2 head:
# Empty DataFrame
# Columns: [YYYYMMSOON, 품목코드 , 품목명, 품종코드 , 품종명, 등급명, 유통단계별 무게 , 유통단계별 단위 , 평균가격(원), 전순 평균가격(원) PreVious SOON, 전달 평균가격(원) PreVious MMonth, 전년 평균가격(원) PreVious YeaR, 평년 평균가격(원) Common Year SOON, year, month, soon, day, date, 품목-품종]
# Index: []
#
# weather head:
# Empty DataFrame
# Columns: [YYYYMMSOON, 지역 이름, 주산지 품목명, 주산지 품종명, 순 평균상대습도, 순 평균기온, 순 평균풍속, 순 최고기온, 순 최저상대습도, 순 최저기온, 순 강수량, 순 누적 일조시간, 특보 코드, 특보 명, 특보 발효 순통계 개수, year, month, soon, day, date]
# Index: []
#
# production head:
# Empty DataFrame
# Columns: [년도, 품목명, 재배면적(ha), 생산량(톤)]
# Index: []
#
# nationwide_market head:
# Empty DataFrame
# Columns: [YYYYMMSOON, 시장코드, 시장명, 품목코드, 품목명, 품종코드, 품종명, 총반입량(kg), 총거래금액(원), 평균가(원/kg), 고가(20%) 평균가, 중가(60%) 평균가 , 저가(20%) 평균가, 중간가(원/kg), 최저가(원/kg), 최고가(원/kg), 경매 건수, 전순 평균가격(원) PreVious SOON, 전달 평균가격(원) PreVious MMonth, 전년 평균가격(원) PreVious YeaR, 평년 평균가격(원) Common Year SOON, 연도]
# Index: []
#
# [0 rows x 22 columns]
#
# retail head:
# Empty DataFrame
# Columns: [YYYYMMSOON, 품목코드 , 품목명, 품종코드 , 품종명, 등급명, 유통단계별 무게 , 유통단계별 단위 , 평균가격(원), 전순 평균가격(원) PreVious SOON, 전달 평균가격(원) PreVious MMonth, 전년 평균가격(원) PreVious YeaR, 평년 평균가격(원) Common Year SOON, year, month, soon, day, date]
# Index: []
#
# wholesale head:
# Empty DataFrame
# Columns: [YYYYMMSOON, 품목코드 , 품목명, 품종코드 , 품종명, 등급명, 유통단계별 무게 , 유통단계별 단위 , 평균가격(원), 전순 평균가격(원) PreVious SOON, 전달 평균가격(원) PreVious MMonth, 전년 평균가격(원) PreVious YeaR, 평년 평균가격(원) Common Year SOON, year, month, soon, day, date]
# Index: []

# %%
missing_value_columns_train = ['평균가격(원)', '전순 평균가격(원) PreVious SOON', '전달 평균가격(원) PreVious MMonth','전년 평균가격(원) PreVious YeaR', '평년 평균가격(원) Common Year SOON']
missing_value_columns_meta_weather = ['순 평균상대습도', '순 평균기온', '순 평균풍속', '순 최고기온', '순 최저상대습도', '순 최저기온', '순 강수량', '순 누적 일조시간']
missing_value_columns_meta_production = ['생산량(톤)', '재배면적(ha)']
missing_value_columns_meta_market = ['평균가(원/kg)', '고가(20%) 평균가', '중가(60%) 평균가 ', '저가(20%) 평균가', '중간가(원/kg)', '최저가(원/kg)', '최고가(원/kg)', '경매 건수', '전순 평균가격(원) PreVious SOON', '전달 평균가격(원) PreVious MMonth', '전년 평균가격(원) PreVious YeaR', '평년 평균가격(원) Common Year SOON']
missing_value_columns_meta_whole = ['유통단계별 무게 ', '유통단계별 단위 ', '평균가격(원)','전순 평균가격(원) PreVious SOON', '전달 평균가격(원) PreVious MMonth', '전년 평균가격(원) PreVious YeaR', '평년 평균가격(원) Common Year SOON']
# Replace zeros with NaN
train_1[missing_value_columns_train] = train_1[missing_value_columns_train].replace(0, np.nan)
train_2[missing_value_columns_train] = train_2[missing_value_columns_train].replace(0, np.nan)
meta_weather[missing_value_columns_meta_weather] = meta_weather[missing_value_columns_meta_weather].replace(0, np.nan)
meta_production[missing_value_columns_meta_production] = meta_production[missing_value_columns_meta_production].replace(0, np.nan)
meta_nationwide_market[missing_value_columns_meta_market] = meta_nationwide_market[missing_value_columns_meta_market].replace(0, np.nan)
meta_wholesale[missing_value_columns_meta_whole] = meta_wholesale[missing_value_columns_meta_whole].replace(0, np.nan)

def count_nans_and_rows(df, group_columns, missing_value_columns):
    nan_counts = df.groupby(group_columns)[missing_value_columns].apply(lambda x: x.isna().sum())
    total_counts = df.groupby(group_columns).size().rename("Total Rows")
    return pd.concat([nan_counts, total_counts], axis=1)

nan_counts_train_1 = count_nans_and_rows(train_1, ['품목(품종)명'], missing_value_columns_train)
nan_counts_train_2 = count_nans_and_rows(train_2, ['품목명', '품종명'], missing_value_columns_train)
nan_counts_meta_weather = count_nans_and_rows(meta_weather, ['주산지 품목명', '주산지 품종명'], missing_value_columns_meta_weather)
nan_counts_meta_nationwide_market = count_nans_and_rows(meta_nationwide_market, ['품목명', '품종명'], missing_value_columns_meta_market)
nan_counts_meta_wholesale = count_nans_and_rows(meta_wholesale, ['품목명', '품종명'], missing_value_columns_meta_whole)

# %%
nan_counts_train_1
# Out:
#          평균가격(원)  전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 품목(품종)명
# 감자 수미          0                         0                           0
# 대파(일반)         0                         0                           0
# 무              0                         1                           3
# 배추             0                         0                           0
# 양파             0                         0                           0
#
#          전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON  Total Rows
# 품목(품종)명
# 감자 수미                           0                            0         180
# 대파(일반)                          0                            0         180
# 무                              36                          180         180
# 배추                              0                            0         180
# 양파                              0                            0         180

# %%
nan_counts_train_2
# Out:
#                  평균가격(원)  전순 평균가격(원) PreVious SOON  \
# 품목명     품종명
# 건고추     화건             0                       180
# 깐마늘(국산) 깐마늘(국산)        0                       180
# 배       신고             0                       180
# 사과      홍로             0                        24
#         후지             0                       156
# 상추      청              0                       180
#
#                  전달 평균가격(원) PreVious MMonth  전년 평균가격(원) PreVious YeaR  \
# 품목명     품종명
# 건고추     화건                                1                         1
# 깐마늘(국산) 깐마늘(국산)                         180                       180
# 배       신고                                0                         0
# 사과      홍로                                9                         0
#         후지                               15                         3
# 상추      청                                 0                         0
#
#                  평년 평균가격(원) Common Year SOON  Total Rows
# 품목명     품종명
# 건고추     화건                                 3         180
# 깐마늘(국산) 깐마늘(국산)                          180         180
# 배       신고                                 0         180
# 사과      홍로                                 0          24
#         후지                                 6         156
# 상추      청                                  0         180

# %%
nan_counts_meta_weather
# Out:
#                  순 평균상대습도  순 평균기온  순 평균풍속  순 최고기온  순 최저상대습도  순 최저기온  순 강수량  \
# 주산지 품목명 주산지 품종명
# 감자      가을              5       0      64       0         0       0    189
#         고랭지             0       0     115       5        22       0    298
#         봄              15       0     234       6        87       0    607
# 건고추     -               9       0     445       7        37       0    711
# 대파      겨울대파            7       0      12       0         0       0    139
# 마늘      난지형 남도         14       0      27       0         0       0    377
#         난지형 대서         10       0     159       6        24       0    304
#         한지형             2       0     153       3        79       0    524
# 무       가을             16       0      72       6        77       0    766
#         고랭지             0       0     104       2        24       0    172
#         봄              12       0      95       6        45       0    477
#         월동              0       0       0       0         0       0     50
# 배       -             181       0     253      16       265       0   1125
# 배추      가을             16       0     284       9       273       0    948
#         겨울              2       0      10       0        23       0    174
#         고랭지             1       0     146       2        37       2    371
#         봄               6       0      51       0         1       0    937
# 사과      -              33       5     704      22        93       2   1529
# 양파      조생종             0       0      10       0         0       0     83
#         중만생종           11       0     304       0         0       0    525
#
#                  순 누적 일조시간  Total Rows
# 주산지 품목명 주산지 품종명
# 감자      가을             390        1185
#         고랭지            193        1214
#         봄             1198        2736
# 건고추     -             1527        3059
# 대파      겨울대파           634         819
# 마늘      난지형 남도        1002        2140
#         난지형 대서         712        1270
#         한지형           1107        2092
# 무       가을            1476        3412
#         고랭지            197         751
#         봄             1304        2702
#         월동               0         471
# 배       -             2114        4602
# 배추      가을            1664        4520
#         겨울             360        1072
#         고랭지            667        1558
#         봄              574        4340
# 사과      -             2418        6075
# 양파      조생종            204         368
#         중만생종          1135        2134

# %%
nan_counts_meta_nationwide_market
# Out:
#               평균가(원/kg)  고가(20%) 평균가  중가(60%) 평균가   저가(20%) 평균가  중간가(원/kg)  \
# 품목명 품종명
# 감자  가을감자              0          218            88            0          0
#     감자                0          125            47            0          0
#     감자(수입)            0          174           108            0          1
#     고냉지               0           24            20            0          0
#     기타감자              0          589           274            0          0
# ...                 ...          ...           ...          ...        ...
# 양파  자주양파(수입)          0           10             8            0          0
#     저장양파              0          326           172            0          0
#     조생양파              2          280           176            2          2
#     중만생양파             0           91            64            0          0
#     중생양파              0          128            70            0          0
#
#               최저가(원/kg)  최고가(원/kg)  경매 건수  전순 평균가격(원) PreVious SOON  \
# 품목명 품종명
# 감자  가을감자              0          0      0                        32
#     감자               13          1      0                        38
#     감자(수입)            9          0      0                        82
#     고냉지               0          0      0                        23
#     기타감자            349          3      0                       127
# ...                 ...        ...    ...                       ...
# 양파  자주양파(수입)          0          0      0                         4
#     저장양파            206          2      0                       152
#     조생양파             58          4      0                       180
#     중만생양파             0          0      0                        57
#     중생양파             35          0      0                        88
#
#               전달 평균가격(원) PreVious MMonth  전년 평균가격(원) PreVious YeaR  \
# 품목명 품종명
# 감자  가을감자                              34                        93
#     감자                                70                       285
#     감자(수입)                           136                       228
#     고냉지                               24                        24
#     기타감자                             155                       253
# ...                                  ...                       ...
# 양파  자주양파(수입)                           8                        10
#     저장양파                             190                       304
#     조생양파                             326                       268
#     중만생양파                             69                        66
#     중생양파                             126                       108
#
#               평년 평균가격(원) Common Year SOON  Total Rows
# 품목명 품종명
# 감자  가을감자                              310         317
#     감자                                592         592
#     감자(수입)                            286         286
#     고냉지                                24          24
#     기타감자                              983        5359
# ...                                   ...         ...
# 양파  자주양파(수입)                           10          10
#     저장양파                              502        1071
#     조생양파                              661         889
#     중만생양파                             114         144
#     중생양파                              211         259
#
# [225 rows x 13 columns]

# %%
nan_counts_meta_wholesale
# Out:
#                   유통단계별 무게   유통단계별 단위   평균가격(원)  전순 평균가격(원) PreVious SOON  \
# 품목명     품종명
# 감자      대지마               0          0        0                        46
#         수미                0          0        0                       360
# 건고추     양건                0          0        0                       358
#         햇산양건              0          0        0                        21
#         햇산화건              0          0        0                        24
#         화건                0          0        0                       179
# 깐마늘(국산) 깐마늘(국산)           0          0        0                         1
#         깐마늘(남도)           0          0        0                       179
#         깐마늘(대서)           0          0        0                       179
#         햇깐마늘(남도)          0          0        0                         7
#         햇깐마늘(대서)          0          0        0                         9
# 무       가을                0          0        0                        68
#         고랭지               0          0        0                       114
#         봄                 0          0        0                        72
#         월동                0          0        0                       184
# 배       신고                0          0        0                       358
#         원황                0          0        0                        44
# 배추      가을                0          0        0                        78
#         봄                 0          0        0                        74
#         여름(고랭지)           0          0        0                       118
#         월동                0          0        0                       154
# 사과      쓰가루               0          0        0                        44
#         홍로                0          0        0                        72
#         후지                0          0        0                       318
# 상추      적                 0          0        0                       360
#         청                 0          0        0                       360
# 양파      수입                0          0        0                        16
#         양파                0          0        0                       360
#         햇양파               0          0        0                        10
# 파       대파                0          0        0                       360
#         쪽파                0          0        0                       360
#
#                   전달 평균가격(원) PreVious MMonth  전년 평균가격(원) PreVious YeaR  \
# 품목명     품종명
# 감자      대지마                               24                        14
#         수미                                 0                         0
# 건고추     양건                                 2                         2
#         햇산양건                              17                        11
#         햇산화건                              20                        12
#         화건                                 1                         1
# 깐마늘(국산) 깐마늘(국산)                            0                         0
#         깐마늘(남도)                            4                        36
#         깐마늘(대서)                            4                        36
#         햇깐마늘(남도)                           5                         5
#         햇깐마늘(대서)                           7                         5
# 무       가을                                30                         6
#         고랭지                               30                        10
#         봄                                 30                         6
#         월동                                32                        12
# 배       신고                                 2                         2
#         원황                                30                         6
# 배추      가을                                30                         4
#         봄                                 30                         4
#         여름(고랭지)                           30                        12
#         월동                                34                         8
# 사과      쓰가루                               30                        10
#         홍로                                30                         6
#         후지                                30                        10
# 상추      적                                  0                         0
#         청                                  0                         0
# 양파      수입                                 0                         0
#         양파                                 0                         0
#         햇양파                               10                         4
# 파       대파                                 0                         0
#         쪽파                                 0                         0
#
#                   평년 평균가격(원) Common Year SOON  Total Rows
# 품목명     품종명
# 감자      대지마                                38          46
#         수미                                  0         360
# 건고추     양건                                  6         358
#         햇산양건                               15          21
#         햇산화건                               18          24
#         화건                                  3         179
# 깐마늘(국산) 깐마늘(국산)                             0           1
#         깐마늘(남도)                           179         179
#         깐마늘(대서)                           179         179
#         햇깐마늘(남도)                            7           7
#         햇깐마늘(대서)                            9           9
# 무       가을                                 12          68
#         고랭지                                26         114
#         봄                                  12          72
#         월동                                 32         184
# 배       신고                                  2         358
#         원황                                 14          44
# 배추      가을                                 16          78
#         봄                                  14          74
#         여름(고랭지)                            28         118
#         월동                                 32         154
# 사과      쓰가루                                14          44
#         홍로                                 14          72
#         후지                                 24         318
# 상추      적                                   0         360
#         청                                   0         360
# 양파      수입                                 16          16
#         양파                                  8         360
#         햇양파                                10          10
# 파       대파                                  0         360
#         쪽파                                  0         360

# %% [markdown]
# ## month,date one hot encoding

# %%
train_1['original_month'] = train_1['month']
train_2['original_month'] = train_2['month']
meta_weather['original_month'] = meta_weather['month']
meta_retail['original_month'] = meta_retail['month']
meta_wholesale['original_month'] = meta_wholesale['month']

train_1['original_day'] = train_1['day']
train_2['original_day'] = train_2['day']
meta_weather['original_day'] = meta_weather['day']
meta_retail['original_day'] = meta_retail['day']
meta_wholesale['original_day'] = meta_wholesale['day']

train_1 = pd.get_dummies(train_1, columns=['month', 'day'], prefix=['month', 'day'])
train_2 = pd.get_dummies(train_2, columns=['month', 'day'], prefix=['month', 'day'])
meta_weather = pd.get_dummies(meta_weather, columns=['month', 'day'], prefix=['month', 'day'])
meta_retail = pd.get_dummies(meta_retail, columns=['month', 'day'], prefix=['month', 'day'])
meta_wholesale = pd.get_dummies(meta_wholesale, columns=['month', 'day'], prefix=['month', 'day'])

# %% [markdown]
# # 배추 feature eng

# %%
cabbage_data = train_1[train_1['품목(품종)명'].str.contains('배추', na=False)].copy()
variety_region_mapping = {
    '봄배추': '봄',
    '여름배추': '고랭지',
    '고랭지배추': '고랭지',
    '김장(가을)배추': '가을',
    '월동배추': '겨울'
}

# Apply the mapping
cabbage_data['주산지'] = cabbage_data['품목(품종)명'].map(variety_region_mapping)

region_mapping = {
    '봄': ['경남', '전남', '충남'],
    '고랭지': ['강원'],
    '가을': ['충북', '경북','경남'],
    '겨울': ['제주']
}

cabbage_data['지역 이름'] = cabbage_data['주산지'].map(region_mapping)

# %%
# def calculate_weather_features(row):
#     end_date = row['date']
#     start_date = end_date - pd.DateOffset(months=4)  # Approximate 4 months
    
#     # Filter weather data by date range
#     mask = (meta_weather['date'] >= start_date) & (meta_weather['date'] <= end_date)
#     subset = meta_weather.loc[mask]
    
#     # Debug: Check date range and subset size
#     print(f"\nProcessing date range: {start_date} to {end_date}")
#     print(f"Subset size: {subset.shape[0]} rows")
    
#     # Count unique regions in the subset
#     unique_regions = subset['지역 이름'].nunique()
#     print(f"Unique regions in subset: {unique_regions}")
    
#     # Calculate expected data points based only on the 1st, 11th, and 21st of each month
#     days_in_range = pd.date_range(start=start_date, end=end_date, freq='10D')  # Approximate the 1st, 11th, 21st
#     total_days = len(days_in_range)
#     expected_data_points = total_days * unique_regions
#     actual_data_points = subset['순 평균기온'].count()
    
#     print(f"Total filtered days: {total_days}")
#     print(f"Expected data points: {expected_data_points}")
#     print(f"Actual data points: {actual_data_points}")
    
#     # If less than 50% data is available, consider the feature as missing
#     if actual_data_points / expected_data_points < 0.5:
#         print("Insufficient data points, returning NaN")
#         return pd.Series({'순 강수량': np.nan, '순 평균기온': np.nan})
#     else:
#         # Calculate cumulative features
#         누적강수량 = subset['순 강수량'].sum(skipna=True)
#         평균기온 = subset['순 평균기온'].mean(skipna=True)
        
#         print(f"누적강수량: {누적강수량}, 평균기온: {평균기온}")
        
#         return pd.Series({'순 강수량': 누적강수량, '순 평균기온': 평균기온})

# # Apply the function and combine results
# weather_features = cabbage_data.apply(calculate_weather_features, axis=1)
# cabbage_data = pd.concat([cabbage_data, weather_features], axis=1)
# Out:
# Processing date range: 2017-09-01 00:00:00 to 2018-01-01 00:00:00
# Subset size: 42 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 42
# Insufficient data points, returning NaN
#
# Processing date range: 2017-09-11 00:00:00 to 2018-01-11 00:00:00
# Subset size: 108 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 108
# Insufficient data points, returning NaN
#
# Processing date range: 2017-09-21 00:00:00 to 2018-01-21 00:00:00
# Subset size: 202 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 202
# 누적강수량: 1.7906040268456305, 평균기온: 0.19189061763319182
#
# Processing date range: 2017-10-01 00:00:00 to 2018-02-01 00:00:00
# Subset size: 277 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 277
# 누적강수량: 2.0697986577181133, 평균기온: 0.18170878459687118
#
# Processing date range: 2017-10-11 00:00:00 to 2018-02-11 00:00:00
# Subset size: 348 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 348
# 누적강수량: 2.1825503355704594, 평균기온: 0.19601806239737268
#
# Processing date range: 2017-10-21 00:00:00 to 2018-02-21 00:00:00
# Subset size: 395 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 395
# 누적강수량: 3.903355704697975, 평균기온: 0.21060880048221814
#
# Processing date range: 2017-11-01 00:00:00 to 2018-03-01 00:00:00
# Subset size: 459 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 459
# 누적강수량: 7.78657718120804, 평균기온: 0.23036622056229894
#
# Processing date range: 2017-11-11 00:00:00 to 2018-03-11 00:00:00
# Subset size: 498 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 498
# 누적강수량: 10.116778523489916, 평균기온: 0.2478007267163893
#
# Processing date range: 2017-11-21 00:00:00 to 2018-03-21 00:00:00
# Subset size: 541 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 541
# 누적강수량: 10.54765100671139, 평균기온: 0.26639380336238
#
# Processing date range: 2017-12-01 00:00:00 to 2018-04-01 00:00:00
# Subset size: 582 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 582
# 누적강수량: 12.995973154362398, 평균기온: 0.2843642611683848
#
# Processing date range: 2017-12-11 00:00:00 to 2018-04-11 00:00:00
# Subset size: 623 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 623
# 누적강수량: 14.036241610738232, 평균기온: 0.3011923870671864
#
# Processing date range: 2017-12-21 00:00:00 to 2018-04-21 00:00:00
# Subset size: 664 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 664
# 누적강수량: 17.69664429530199, 평균기온: 0.3196356855995409
#
# Processing date range: 2018-01-01 00:00:00 to 2018-05-01 00:00:00
# Subset size: 710 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 710
# 누적강수량: 20.276510067114067, 평균기온: 0.3390342052313883
#
# Processing date range: 2018-01-11 00:00:00 to 2018-05-11 00:00:00
# Subset size: 710 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 710
# 누적강수량: 23.012080536912727, 평균기온: 0.3661301140174379
#
# Processing date range: 2018-01-21 00:00:00 to 2018-05-21 00:00:00
# Subset size: 684 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 684
# 누적강수량: 22.985234899328837, 평균기온: 0.3965817321080478
#
# Processing date range: 2018-02-01 00:00:00 to 2018-06-01 00:00:00
# Subset size: 629 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 629
# 누적강수량: 23.174496644295278, 평균기온: 0.45911878264819433
#
# Processing date range: 2018-02-11 00:00:00 to 2018-06-11 00:00:00
# Subset size: 593 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 593
# 누적강수량: 23.558389261744946, 평균기온: 0.5166626515699028
#
# Processing date range: 2018-02-21 00:00:00 to 2018-06-21 00:00:00
# Subset size: 593 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 593
# 누적강수량: 36.81476510067111, 평균기온: 0.5854011081667067
#
# Processing date range: 2018-03-01 00:00:00 to 2018-07-01 00:00:00
# Subset size: 597 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 597
# 누적강수량: 45.178523489932864, 평균기온: 0.6252692031586503
#
# Processing date range: 2018-03-11 00:00:00 to 2018-07-11 00:00:00
# Subset size: 585 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 585
# 누적강수량: 41.5194630872483, 평균기온: 0.6800569800569799
#
# Processing date range: 2018-03-21 00:00:00 to 2018-07-21 00:00:00
# Subset size: 590 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 590
# 누적강수량: 39.520805369127494, 평균기온: 0.7149313962873284
#
# Processing date range: 2018-04-01 00:00:00 to 2018-08-01 00:00:00
# Subset size: 591 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 591
# 누적강수량: 40.40671140939595, 평균기온: 0.7491741197324954
#
# Processing date range: 2018-04-11 00:00:00 to 2018-08-11 00:00:00
# Subset size: 630 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 630
# 누적강수량: 39.13020134228186, 평균기온: 0.7848828420256991
#
# Processing date range: 2018-04-21 00:00:00 to 2018-08-21 00:00:00
# Subset size: 723 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 723
# 누적강수량: 87.3677852348993, 평균기온: 0.8124876506619244
#
# Processing date range: 2018-05-01 00:00:00 to 2018-09-01 00:00:00
# Subset size: 724 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 724
# 누적강수량: 87.42416107382547, 평균기온: 0.8224480399894765
#
# Processing date range: 2018-05-11 00:00:00 to 2018-09-11 00:00:00
# Subset size: 717 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 717
# 누적강수량: 86.41073825503352, 평균기온: 0.8317393903167962
#
# Processing date range: 2018-05-21 00:00:00 to 2018-09-21 00:00:00
# Subset size: 714 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 714
# 누적강수량: 84.60268456375836, 평균기온: 0.8315993063892224
#
# Processing date range: 2018-06-01 00:00:00 to 2018-10-01 00:00:00
# Subset size: 752 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 752
# 누적강수량: 100.92214765100668, 평균기온: 0.8187689969604862
#
# Processing date range: 2018-06-11 00:00:00 to 2018-10-11 00:00:00
# Subset size: 752 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 752
# 누적강수량: 100.79731543624158, 평균기온: 0.8065159574468085
#
# Processing date range: 2018-06-21 00:00:00 to 2018-10-21 00:00:00
# Subset size: 752 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 752
# 누적강수량: 100.87919463087245, 평균기온: 0.7939779635258358
#
# Processing date range: 2018-07-01 00:00:00 to 2018-11-01 00:00:00
# Subset size: 720 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 720
# 누적강수량: 89.55704697986573, 평균기온: 0.7749338624338624
#
# Processing date range: 2018-07-11 00:00:00 to 2018-11-11 00:00:00
# Subset size: 708 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 708
# 누적강수량: 79.64832214765097, 평균기온: 0.7536655905299973
#
# Processing date range: 2018-07-21 00:00:00 to 2018-11-21 00:00:00
# Subset size: 696 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 696
# 누적강수량: 79.79731543624158, 평균기온: 0.7201354679802956
#
# Processing date range: 2018-08-01 00:00:00 to 2018-12-01 00:00:00
# Subset size: 713 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 713
# 누적강수량: 81.28187919463085, 평균기온: 0.6707072730915647
#
# Processing date range: 2018-08-11 00:00:00 to 2018-12-11 00:00:00
# Subset size: 731 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 731
# 누적강수량: 80.31543624161071, 평균기온: 0.6186241938635919
#
# Processing date range: 2018-08-21 00:00:00 to 2018-12-21 00:00:00
# Subset size: 737 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 737
# 누적강수량: 79.37583892617445, 평균기온: 0.5416747431672805
#
# Processing date range: 2018-09-01 00:00:00 to 2019-01-01 00:00:00
# Subset size: 667 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 667
# 누적강수량: 30.102013422818768, 평균기온: 0.4453487541943313
#
# Processing date range: 2018-09-11 00:00:00 to 2019-01-11 00:00:00
# Subset size: 676 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 676
# 누적강수량: 26.567785234899304, 평균기온: 0.4113482671174979
#
# Processing date range: 2018-09-21 00:00:00 to 2019-01-21 00:00:00
# Subset size: 686 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 686
# 누적강수량: 25.27114093959729, 평균기온: 0.3815077051228654
#
# Processing date range: 2018-10-01 00:00:00 to 2019-02-01 00:00:00
# Subset size: 705 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 705
# 누적강수량: 24.912751677852327, 평균기온: 0.3572104018912529
#
# Processing date range: 2018-10-11 00:00:00 to 2019-02-11 00:00:00
# Subset size: 680 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 680
# 누적강수량: 8.280536912751657, 평균기온: 0.3179621848739495
#
# Processing date range: 2018-10-21 00:00:00 to 2019-02-21 00:00:00
# Subset size: 680 rows
# Unique regions in subset: 20
# Total filtered days: 13
# Expected data points: 260
# Actual data points: 680
# 누적강수량: 8.076510067114075, 평균기온: 0.3082282913165265
#
# Processing date range: 2018-11-01 00:00:00 to 2019-03-01 00:00:00
# Subset size: 742 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 742
# 누적강수량: 8.927516778523469, 평균기온: 0.3141445257348221
#
# Processing date range: 2018-11-11 00:00:00 to 2019-03-11 00:00:00
# Subset size: 814 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 814
# 누적강수량: 10.387919463087222, 평균기온: 0.3191470691470691
#
# Processing date range: 2018-11-21 00:00:00 to 2019-03-21 00:00:00
# Subset size: 900 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 900
# 누적강수량: 11.144966442952992, 평균기온: 0.33124338624338623
#
# Processing date range: 2018-12-01 00:00:00 to 2019-04-01 00:00:00
# Subset size: 915 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 915
# 누적강수량: 13.267114093959702, 평균기온: 0.3373666406453291
#
# Processing date range: 2018-12-11 00:00:00 to 2019-04-11 00:00:00
# Subset size: 897 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 897
# 누적강수량: 11.492617449664403, 평균기온: 0.34896745766310977
#
# Processing date range: 2018-12-21 00:00:00 to 2019-04-21 00:00:00
# Subset size: 876 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 876
# 누적강수량: 12.90335570469796, 평균기온: 0.3667916938464883
#
# Processing date range: 2019-01-01 00:00:00 to 2019-05-01 00:00:00
# Subset size: 832 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 832
# 누적강수량: 12.67114093959729, 평균기온: 0.3932577838827838
#
# Processing date range: 2019-01-11 00:00:00 to 2019-05-11 00:00:00
# Subset size: 814 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 814
# 누적강수량: 14.314093959731514, 평균기온: 0.4262314262314262
#
# Processing date range: 2019-01-21 00:00:00 to 2019-05-21 00:00:00
# Subset size: 812 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 812
# 누적강수량: 15.021476510067084, 평균기온: 0.454550785831574
#
# Processing date range: 2019-02-01 00:00:00 to 2019-06-01 00:00:00
# Subset size: 823 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 823
# 누적강수량: 18.832214765100638, 평균기온: 0.4859978013076433
#
# Processing date range: 2019-02-11 00:00:00 to 2019-06-11 00:00:00
# Subset size: 807 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 807
# 누적강수량: 18.60268456375836, 평균기온: 0.5134242048740189
#
# Processing date range: 2019-02-21 00:00:00 to 2019-06-21 00:00:00
# Subset size: 800 rows
# Unique regions in subset: 55
# Total filtered days: 13
# Expected data points: 715
# Actual data points: 800
# 누적강수량: 21.59731543624158, 평균기온: 0.5452083333333333
#
# Processing date range: 2019-03-01 00:00:00 to 2019-07-01 00:00:00
# Subset size: 1021 rows
# Unique regions in subset: 118
# Total filtered days: 13
# Expected data points: 1534
# Actual data points: 1021
# 누적강수량: 30.20134228187915, 평균기온: 0.6179515880789141
#
# Processing date range: 2019-03-11 00:00:00 to 2019-07-11 00:00:00
# Subset size: 1191 rows
# Unique regions in subset: 118
# Total filtered days: 13
# Expected data points: 1534
# Actual data points: 1191
# 누적강수량: 71.83087248322143, 평균기온: 0.6790212306585102
#
# Processing date range: 2019-03-21 00:00:00 to 2019-07-21 00:00:00
# Subset size: 1417 rows
# Unique regions in subset: 118
# Total filtered days: 13
# Expected data points: 1534
# Actual data points: 1417
# 누적강수량: 107.33691275167779, 평균기온: 0.7498907820008738
#
# Processing date range: 2019-04-01 00:00:00 to 2019-08-01 00:00:00
# Subset size: 1636 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 1636
# 누적강수량: 122.31006711409388, 평균기온: 0.8086505996041449
#
# Processing date range: 2019-04-11 00:00:00 to 2019-08-11 00:00:00
# Subset size: 1970 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 1970
# 누적강수량: 155.38926174496635, 평균기온: 0.8275803722504231
#
# Processing date range: 2019-04-21 00:00:00 to 2019-08-21 00:00:00
# Subset size: 2197 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 2197
# 누적강수량: 177.20268456375828, 평균기온: 0.831306760300843
#
# Processing date range: 2019-05-01 00:00:00 to 2019-09-01 00:00:00
# Subset size: 2516 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 2516
# 누적강수량: 225.7704697986576, 평균기온: 0.8336740101445982
#
# Processing date range: 2019-05-11 00:00:00 to 2019-09-11 00:00:00
# Subset size: 2770 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 2770
# 누적강수량: 230.64697986577167, 평균기온: 0.8290441808492349
#
# Processing date range: 2019-05-21 00:00:00 to 2019-09-21 00:00:00
# Subset size: 3006 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3006
# 누적강수량: 274.614765100671, 평균기온: 0.8207157114342742
#
# Processing date range: 2019-06-01 00:00:00 to 2019-10-01 00:00:00
# Subset size: 3244 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3244
# 누적강수량: 331.52348993288575, 평균기온: 0.80980271270037
#
# Processing date range: 2019-06-11 00:00:00 to 2019-10-11 00:00:00
# Subset size: 3438 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3438
# 누적강수량: 330.62684563758376, 평균기온: 0.7969126568603008
#
# Processing date range: 2019-06-21 00:00:00 to 2019-10-21 00:00:00
# Subset size: 3650 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3650
# 누적강수량: 331.0791946308723, 평균기온: 0.7825766470971952
#
# Processing date range: 2019-07-01 00:00:00 to 2019-11-01 00:00:00
# Subset size: 3858 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3858
# 누적강수량: 330.12885906040253, 평균기온: 0.7653607840233034
#
# Processing date range: 2019-07-11 00:00:00 to 2019-11-11 00:00:00
# Subset size: 3864 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3864
# 누적강수량: 333.15033557046957, 평균기온: 0.7403566499063394
#
# Processing date range: 2019-07-21 00:00:00 to 2019-11-21 00:00:00
# Subset size: 3852 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3852
# 누적강수량: 293.2093959731542, 평균기온: 0.7136985115957079
#
# Processing date range: 2019-08-01 00:00:00 to 2019-12-01 00:00:00
# Subset size: 3777 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3777
# 누적강수량: 259.2134228187918, 평균기온: 0.6705624267181057
#
# Processing date range: 2019-08-11 00:00:00 to 2019-12-11 00:00:00
# Subset size: 3723 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3723
# 누적강수량: 244.63489932885892, 평균기온: 0.6232876712328768
#
# Processing date range: 2019-08-21 00:00:00 to 2019-12-21 00:00:00
# Subset size: 3724 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3724
# 누적강수량: 213.4335570469797, 평균기온: 0.5670170323768605
#
# Processing date range: 2019-09-01 00:00:00 to 2020-01-01 00:00:00
# Subset size: 3759 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3759
# 누적강수량: 211.9261744966442, 평균기온: 0.5302195366042133
#
# Processing date range: 2019-09-11 00:00:00 to 2020-01-11 00:00:00
# Subset size: 3661 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3661
# 누적강수량: 162.0120805369126, 평균기온: 0.48391019887878656
#
# Processing date range: 2019-09-21 00:00:00 to 2020-01-21 00:00:00
# Subset size: 3673 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3673
# 누적강수량: 171.20402684563743, 평균기온: 0.4521605538485472
#
# Processing date range: 2019-10-01 00:00:00 to 2020-02-01 00:00:00
# Subset size: 3674 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3674
# 누적강수량: 125.93288590604014, 평균기온: 0.418001659019623
#
# Processing date range: 2019-10-11 00:00:00 to 2020-02-11 00:00:00
# Subset size: 3774 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3774
# 누적강수량: 78.82147651006699, 평균기온: 0.39284452519746627
#
# Processing date range: 2019-10-21 00:00:00 to 2020-02-21 00:00:00
# Subset size: 3832 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3832
# 누적강수량: 91.20805369127503, 평균기온: 0.3786410179938363
#
# Processing date range: 2019-11-01 00:00:00 to 2020-03-01 00:00:00
# Subset size: 3851 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3851
# 누적강수량: 95.86711409395957, 평균기온: 0.366089203793696
#
# Processing date range: 2019-11-11 00:00:00 to 2020-03-11 00:00:00
# Subset size: 3971 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3971
# 누적강수량: 93.83892617449649, 평균기온: 0.36166972455061086
#
# Processing date range: 2019-11-21 00:00:00 to 2020-03-21 00:00:00
# Subset size: 4021 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4021
# 누적강수량: 88.99597315436228, 평균기온: 0.3679373763929844
#
# Processing date range: 2019-12-01 00:00:00 to 2020-04-01 00:00:00
# Subset size: 4051 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4051
# 누적강수량: 86.30604026845623, 평균기온: 0.3721891126235732
#
# Processing date range: 2019-12-11 00:00:00 to 2020-04-11 00:00:00
# Subset size: 4108 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4108
# 누적강수량: 100.15033557046965, 평균기온: 0.3867482728242221
#
# Processing date range: 2019-12-21 00:00:00 to 2020-04-21 00:00:00
# Subset size: 4202 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4202
# 누적강수량: 98.97852348993275, 평균기온: 0.4021271050066861
#
# Processing date range: 2020-01-01 00:00:00 to 2020-05-01 00:00:00
# Subset size: 4152 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4152
# 누적강수량: 120.19194630872468, 평균기온: 0.43198343884760065
#
# Processing date range: 2020-01-11 00:00:00 to 2020-05-11 00:00:00
# Subset size: 4153 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4153
# 누적강수량: 119.69932885906026, 평균기온: 0.45564881382362715
#
# Processing date range: 2020-01-21 00:00:00 to 2020-05-21 00:00:00
# Subset size: 4145 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4145
# 누적강수량: 121.29932885906027, 평균기온: 0.4805904991670974
#
# Processing date range: 2020-02-01 00:00:00 to 2020-06-01 00:00:00
# Subset size: 4093 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4093
# 누적강수량: 111.66577181208041, 평균기온: 0.5079403860249205
#
# Processing date range: 2020-02-11 00:00:00 to 2020-06-11 00:00:00
# Subset size: 4080 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4080
# 누적강수량: 141.1892617449663, 평균기온: 0.5428571428571427
#
# Processing date range: 2020-02-21 00:00:00 to 2020-06-21 00:00:00
# Subset size: 4047 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4047
# 누적강수량: 174.6308724832213, 평균기온: 0.5814595173379458
#
# Processing date range: 2020-03-01 00:00:00 to 2020-07-01 00:00:00
# Subset size: 3989 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3989
# 누적강수량: 176.69798657718104, 평균기온: 0.6084649452661485
#
# Processing date range: 2020-03-11 00:00:00 to 2020-07-11 00:00:00
# Subset size: 4017 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4017
# 누적강수량: 225.1892617449663, 평균기온: 0.6361297817608497
#
# Processing date range: 2020-03-21 00:00:00 to 2020-07-21 00:00:00
# Subset size: 4041 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4041
# 누적강수량: 345.4053691275166, 평균기온: 0.6715157728520756
#
# Processing date range: 2020-04-01 00:00:00 to 2020-08-01 00:00:00
# Subset size: 4335 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4335
# 누적강수량: 564.3785234899326, 평균기온: 0.7089251386829242
#
# Processing date range: 2020-04-11 00:00:00 to 2020-08-11 00:00:00
# Subset size: 4486 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4486
# 누적강수량: 585.9302013422816, 평균기온: 0.7420705687535825
#
# Processing date range: 2020-04-21 00:00:00 to 2020-08-21 00:00:00
# Subset size: 4724 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4724
# 누적강수량: 623.3516778523489, 평균기온: 0.7745907423087779
#
# Processing date range: 2020-05-01 00:00:00 to 2020-09-01 00:00:00
# Subset size: 4885 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4885
# 누적강수량: 772.6469798657715, 평균기온: 0.7957498659648096
#
# Processing date range: 2020-05-11 00:00:00 to 2020-09-11 00:00:00
# Subset size: 4799 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4799
# 누적강수량: 756.3194630872481, 평균기온: 0.8013028507923278
#
# Processing date range: 2020-05-21 00:00:00 to 2020-09-21 00:00:00
# Subset size: 4747 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4747
# 누적강수량: 737.546308724832, 평균기온: 0.8047288011475919
#
# Processing date range: 2020-06-01 00:00:00 to 2020-10-01 00:00:00
# Subset size: 4747 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4747
# 누적강수량: 736.794630872483, 평균기온: 0.8031187617241966
#
# Processing date range: 2020-06-11 00:00:00 to 2020-10-11 00:00:00
# Subset size: 4745 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4745
# 누적강수량: 732.4201342281877, 평균기온: 0.7916453409604094
#
# Processing date range: 2020-06-21 00:00:00 to 2020-10-21 00:00:00
# Subset size: 4731 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4731
# 누적강수량: 705.1892617449662, 평균기온: 0.7773952954675845
#
# Processing date range: 2020-07-01 00:00:00 to 2020-11-01 00:00:00
# Subset size: 4641 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4641
# 누적강수량: 662.3006711409394, 평균기온: 0.7592318978873601
#
# Processing date range: 2020-07-11 00:00:00 to 2020-11-11 00:00:00
# Subset size: 4691 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4691
# 누적강수량: 656.3892617449662, 평균기온: 0.7437240511211946
#
# Processing date range: 2020-07-21 00:00:00 to 2020-11-21 00:00:00
# Subset size: 4644 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4644
# 누적강수량: 602.6738255033555, 평균기온: 0.7213762766088347
#
# Processing date range: 2020-08-01 00:00:00 to 2020-12-01 00:00:00
# Subset size: 4500 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4500
# 누적강수량: 481.6120805369127, 평균기온: 0.692037037037037
#
# Processing date range: 2020-08-11 00:00:00 to 2020-12-11 00:00:00
# Subset size: 4252 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4252
# 누적강수량: 256.97583892617433, 평균기온: 0.6293172960623573
#
# Processing date range: 2020-08-21 00:00:00 to 2020-12-21 00:00:00
# Subset size: 4222 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4222
# 누적강수량: 238.66845637583882, 평균기온: 0.5681069680359117
#
# Processing date range: 2020-09-01 00:00:00 to 2021-01-01 00:00:00
# Subset size: 4307 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4302
# 누적강수량: 184.59328859060392, 평균기온: 0.46390383210466885
#
# Processing date range: 2020-09-11 00:00:00 to 2021-01-11 00:00:00
# Subset size: 4299 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4294
# 누적강수량: 36.846979865771694, 평균기온: 0.39450395901257557
#
# Processing date range: 2020-09-21 00:00:00 to 2021-01-21 00:00:00
# Subset size: 4565 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4560
# 누적강수량: 38.264429530201205, 평균기온: 0.3689954051796156
#
# Processing date range: 2020-10-01 00:00:00 to 2021-02-01 00:00:00
# Subset size: 4643 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4638
# 누적강수량: 41.00939597315421, 평균기온: 0.34613133739912516
#
# Processing date range: 2020-10-11 00:00:00 to 2021-02-11 00:00:00
# Subset size: 4918 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4913
# 누적강수량: 43.026845637583726, 평균기온: 0.32902503561978413
#
# Processing date range: 2020-10-21 00:00:00 to 2021-02-21 00:00:00
# Subset size: 5038 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5033
# 누적강수량: 45.194630872483046, 평균기온: 0.3228359494006225
#
# Processing date range: 2020-11-01 00:00:00 to 2021-03-01 00:00:00
# Subset size: 5079 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5074
# 누적강수량: 65.01476510067096, 평균기온: 0.3163278713140754
#
# Processing date range: 2020-11-11 00:00:00 to 2021-03-11 00:00:00
# Subset size: 5069 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5064
# 누적강수량: 70.76375838926157, 평균기온: 0.31567836455277204
#
# Processing date range: 2020-11-21 00:00:00 to 2021-03-21 00:00:00
# Subset size: 5054 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5049
# 누적강수량: 69.83221476510049, 평균기온: 0.31350385271953896
#
# Processing date range: 2020-12-01 00:00:00 to 2021-04-01 00:00:00
# Subset size: 5066 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5061
# 누적강수량: 83.64161073825484, 평균기온: 0.3222495083787318
#
# Processing date range: 2020-12-11 00:00:00 to 2021-04-11 00:00:00
# Subset size: 5144 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5139
# 누적강수량: 93.98523489932865, 평균기온: 0.3361039297992012
#
# Processing date range: 2020-12-21 00:00:00 to 2021-04-21 00:00:00
# Subset size: 5090 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5085
# 누적강수량: 97.5973154362414, 평균기온: 0.3616800112375333
#
# Processing date range: 2021-01-01 00:00:00 to 2021-05-01 00:00:00
# Subset size: 5009 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5004
# 누적강수량: 108.66040268456355, 평균기온: 0.38397377336226246
#
# Processing date range: 2021-01-11 00:00:00 to 2021-05-11 00:00:00
# Subset size: 4628 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4628
# 누적강수량: 130.23221476510048, 평균기온: 0.4337778326542371
#
# Processing date range: 2021-01-21 00:00:00 to 2021-05-21 00:00:00
# Subset size: 4352 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4352
# 누적강수량: 138.96375838926156, 평균기온: 0.471813725490196
#
# Processing date range: 2021-02-01 00:00:00 to 2021-06-01 00:00:00
# Subset size: 4086 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4086
# 누적강수량: 137.89530201342262, 평균기온: 0.507266391627625
#
# Processing date range: 2021-02-11 00:00:00 to 2021-06-11 00:00:00
# Subset size: 4021 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4021
# 누적강수량: 150.46711409395954, 평균기온: 0.5428287206451841
#
# Processing date range: 2021-02-21 00:00:00 to 2021-06-21 00:00:00
# Subset size: 3746 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3746
# 누적강수량: 154.5771812080535, 평균기온: 0.5883736302850023
#
# Processing date range: 2021-03-01 00:00:00 to 2021-07-01 00:00:00
# Subset size: 3846 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3846
# 누적강수량: 277.7275167785233, 평균기온: 0.6350754030161205
#
# Processing date range: 2021-03-11 00:00:00 to 2021-07-11 00:00:00
# Subset size: 3976 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 3976
# 누적강수량: 268.3731543624159, 평균기온: 0.679864903707962
#
# Processing date range: 2021-03-21 00:00:00 to 2021-07-21 00:00:00
# Subset size: 4034 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4034
# 누적강수량: 265.60671140939576, 평균기온: 0.711092617513044
#
# Processing date range: 2021-04-01 00:00:00 to 2021-08-01 00:00:00
# Subset size: 4262 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4262
# 누적강수량: 304.67248322147634, 평균기온: 0.7468157136153382
#
# Processing date range: 2021-04-11 00:00:00 to 2021-08-11 00:00:00
# Subset size: 4393 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4393
# 누적강수량: 312.49261744966424, 평균기온: 0.7671566236328358
#
# Processing date range: 2021-04-21 00:00:00 to 2021-08-21 00:00:00
# Subset size: 4516 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4516
# 누적강수량: 409.6416107382548, 평균기온: 0.7891359821164957
#
# Processing date range: 2021-05-01 00:00:00 to 2021-09-01 00:00:00
# Subset size: 4510 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4510
# 누적강수량: 433.8765100671139, 평균기온: 0.7991500369549148
#
# Processing date range: 2021-05-11 00:00:00 to 2021-09-11 00:00:00
# Subset size: 4448 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4448
# 누적강수량: 432.7073825503354, 평균기온: 0.8123929427886262
#
# Processing date range: 2021-05-21 00:00:00 to 2021-09-21 00:00:00
# Subset size: 4481 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4481
# 누적강수량: 431.4550335570468, 평균기온: 0.8157936685051168
#
# Processing date range: 2021-06-01 00:00:00 to 2021-10-01 00:00:00
# Subset size: 4474 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4474
# 누적강수량: 427.67785234899304, 평균기온: 0.8209070396151309
#
# Processing date range: 2021-06-11 00:00:00 to 2021-10-11 00:00:00
# Subset size: 4543 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4543
# 누적강수량: 430.78791946308706, 평균기온: 0.8074274393886984
#
# Processing date range: 2021-06-21 00:00:00 to 2021-10-21 00:00:00
# Subset size: 4530 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4530
# 누적강수량: 414.86174496644276, 평균기온: 0.7935982339955849
#
# Processing date range: 2021-07-01 00:00:00 to 2021-11-01 00:00:00
# Subset size: 4549 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4549
# 누적강수량: 419.2120805369126, 평균기온: 0.7778842027028442
#
# Processing date range: 2021-07-11 00:00:00 to 2021-11-11 00:00:00
# Subset size: 4349 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4349
# 누적강수량: 294.52348993288575, 평균기온: 0.7527948406311248
#
# Processing date range: 2021-07-21 00:00:00 to 2021-11-21 00:00:00
# Subset size: 4271 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4271
# 누적강수량: 293.3395973154361, 평균기온: 0.7117659519907237
#
# Processing date range: 2021-08-01 00:00:00 to 2021-12-01 00:00:00
# Subset size: 4274 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4274
# 누적강수량: 290.104697986577, 평균기온: 0.6714575394968468
#
# Processing date range: 2021-08-11 00:00:00 to 2021-12-11 00:00:00
# Subset size: 4190 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4190
# 누적강수량: 241.75302013422805, 평균기온: 0.6079838618024775
#
# Processing date range: 2021-08-21 00:00:00 to 2021-12-21 00:00:00
# Subset size: 4325 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4325
# 누적강수량: 222.83624161073809, 평균기온: 0.5440957886044591
#
# Processing date range: 2021-09-01 00:00:00 to 2022-01-01 00:00:00
# Subset size: 4166 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4166
# 누적강수량: 115.53825503355688, 평균기온: 0.4941362046498867
#
# Processing date range: 2021-09-11 00:00:00 to 2022-01-11 00:00:00
# Subset size: 4346 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4346
# 누적강수량: 87.75302013422805, 평균기온: 0.4432921350776849
#
# Processing date range: 2021-09-21 00:00:00 to 2022-01-21 00:00:00
# Subset size: 4361 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4361
# 누적강수량: 74.3382550335569, 평균기온: 0.4122852993524857
#
# Processing date range: 2021-10-01 00:00:00 to 2022-02-01 00:00:00
# Subset size: 4406 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4406
# 누적강수량: 52.315436241610605, 평균기온: 0.3762888269243239
#
# Processing date range: 2021-10-11 00:00:00 to 2022-02-11 00:00:00
# Subset size: 4528 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4528
# 누적강수량: 46.158389261744844, 평균기온: 0.34494888944977276
#
# Processing date range: 2021-10-21 00:00:00 to 2022-02-21 00:00:00
# Subset size: 4571 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4571
# 누적강수량: 33.85771812080525, 평균기온: 0.32354595743350933
#
# Processing date range: 2021-11-01 00:00:00 to 2022-03-01 00:00:00
# Subset size: 4723 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4723
# 누적강수량: 33.92751677852337, 평균기온: 0.3172267424861114
#
# Processing date range: 2021-11-11 00:00:00 to 2022-03-11 00:00:00
# Subset size: 4804 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4804
# 누적강수량: 43.51006711409383, 평균기온: 0.31663593830538034
#
# Processing date range: 2021-11-21 00:00:00 to 2022-03-21 00:00:00
# Subset size: 4892 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4892
# 누적강수량: 63.94496644295288, 평균기온: 0.3196959077989331
#
# Processing date range: 2021-12-01 00:00:00 to 2022-04-01 00:00:00
# Subset size: 4843 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4843
# 누적강수량: 52.126174496644175, 평균기온: 0.3261654031837801
#
# Processing date range: 2021-12-11 00:00:00 to 2022-04-11 00:00:00
# Subset size: 4832 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4832
# 누적강수량: 56.00939597315424, 평균기온: 0.3397144039735098
#
# Processing date range: 2021-12-21 00:00:00 to 2022-04-21 00:00:00
# Subset size: 4805 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4805
# 누적강수량: 83.26308724832201, 평균기온: 0.36527922303156424
#
# Processing date range: 2022-01-01 00:00:00 to 2022-05-01 00:00:00
# Subset size: 4557 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4557
# 누적강수량: 80.6456375838925, 평균기온: 0.393721851259705
#
# Processing date range: 2022-01-11 00:00:00 to 2022-05-11 00:00:00
# Subset size: 4541 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4541
# 누적강수량: 81.02416107382537, 평균기온: 0.41977852581243896
#
# Processing date range: 2022-01-21 00:00:00 to 2022-05-21 00:00:00
# Subset size: 4341 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4341
# 누적강수량: 80.60536912751665, 평균기온: 0.4636960981121312
#
# Processing date range: 2022-02-01 00:00:00 to 2022-06-01 00:00:00
# Subset size: 4350 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4350
# 누적강수량: 94.81476510067102, 평균기온: 0.49293924466338246
#
# Processing date range: 2022-02-11 00:00:00 to 2022-06-11 00:00:00
# Subset size: 4281 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4281
# 누적강수량: 100.79328859060388, 평균기온: 0.5307616155548881
#
# Processing date range: 2022-02-21 00:00:00 to 2022-06-21 00:00:00
# Subset size: 4440 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4440
# 누적강수량: 192.40805369127497, 평균기온: 0.5940208065208065
#
# Processing date range: 2022-03-01 00:00:00 to 2022-07-01 00:00:00
# Subset size: 4447 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4447
# 누적강수량: 200.34496644295285, 평균기온: 0.644832792572842
#
# Processing date range: 2022-03-11 00:00:00 to 2022-07-11 00:00:00
# Subset size: 4487 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4487
# 누적강수량: 253.9087248322146, 평균기온: 0.6901153597164295
#
# Processing date range: 2022-03-21 00:00:00 to 2022-07-21 00:00:00
# Subset size: 4483 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4483
# 누적강수량: 263.71946308724813, 평균기온: 0.7218539880819604
#
# Processing date range: 2022-04-01 00:00:00 to 2022-08-01 00:00:00
# Subset size: 4551 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4551
# 누적강수량: 318.62013422818774, 평균기온: 0.7595871132456498
#
# Processing date range: 2022-04-11 00:00:00 to 2022-08-11 00:00:00
# Subset size: 4724 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4724
# 누적강수량: 385.48993288590583, 평균기온: 0.7858957300108866
#
# Processing date range: 2022-04-21 00:00:00 to 2022-08-21 00:00:00
# Subset size: 4737 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4737
# 누적강수량: 405.52751677852325, 평균기온: 0.7993958402444785
#
# Processing date range: 2022-05-01 00:00:00 to 2022-09-01 00:00:00
# Subset size: 4693 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4693
# 누적강수량: 443.27919463087227, 평균기온: 0.8122025712053411
#
# Processing date range: 2022-05-11 00:00:00 to 2022-09-11 00:00:00
# Subset size: 4797 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4797
# 누적강수량: 448.9355704697984, 평균기온: 0.82330722574625
#
# Processing date range: 2022-05-21 00:00:00 to 2022-09-21 00:00:00
# Subset size: 4812 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4812
# 누적강수량: 448.4201342281877, 평균기온: 0.8235561888928472
#
# Processing date range: 2022-06-01 00:00:00 to 2022-10-01 00:00:00
# Subset size: 4888 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4888
# 누적강수량: 482.904697986577, 평균기온: 0.8160899384303639
#
# Processing date range: 2022-06-11 00:00:00 to 2022-10-11 00:00:00
# Subset size: 4983 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4983
# 누적강수량: 468.3798657718119, 평균기온: 0.802213239299332
#
# Processing date range: 2022-06-21 00:00:00 to 2022-10-21 00:00:00
# Subset size: 5002 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5002
# 누적강수량: 463.8255033557045, 평균기온: 0.789579406332705
#
# Processing date range: 2022-07-01 00:00:00 to 2022-11-01 00:00:00
# Subset size: 4767 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4767
# 누적강수량: 371.7409395973153, 평균기온: 0.7624092221323183
#
# Processing date range: 2022-07-11 00:00:00 to 2022-11-11 00:00:00
# Subset size: 4682 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4682
# 누적강수량: 373.5087248322146, 평균기온: 0.7361729826488476
#
# Processing date range: 2022-07-21 00:00:00 to 2022-11-21 00:00:00
# Subset size: 4871 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 4871
# 누적강수량: 346.0926174496642, 평균기온: 0.6899629488420291
#
# Processing date range: 2022-08-01 00:00:00 to 2022-12-01 00:00:00
# Subset size: 5061 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5061
# 누적강수량: 315.22013422818776, 평균기온: 0.6362520111779151
#
# Processing date range: 2022-08-11 00:00:00 to 2022-12-11 00:00:00
# Subset size: 5484 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5484
# 누적강수량: 247.46040268456358, 평균기온: 0.5517783335069987
#
# Processing date range: 2022-08-21 00:00:00 to 2022-12-21 00:00:00
# Subset size: 5309 rows
# Unique regions in subset: 116
# Total filtered days: 13
# Expected data points: 1508
# Actual data points: 5309
# 누적강수량: 183.6872483221475, 평균기온: 0.5037940962785565

# %%
import pandas as pd
import numpy as np

def calculate_weather_features(row):
    end_date = row['date']
    start_date = end_date - pd.DateOffset(months=4)  # Approximate 4 months
    
    # Filter general weather data by date range
    general_mask = (meta_weather['date'] >= start_date) & (meta_weather['date'] <= end_date)
    general_subset = meta_weather.loc[general_mask]
    
    # Filter specific weather data by date range and 주산지 품목명
    specific_mask = general_mask & (meta_weather['주산지 품목명'].str.contains(row['품목(품종)명'], na=False))
    specific_subset = meta_weather.loc[specific_mask]
    
    # Calculate expected and actual data points for general weather data
    unique_regions = general_subset['지역 이름'].nunique()
    days_in_range = pd.date_range(start=start_date, end=end_date, freq='10D')  # Expected 1st, 11th, 21st of each month
    expected_data_points = len(days_in_range) * unique_regions
    actual_data_points_general = general_subset['순 평균기온'].count()

    # Calculate expected and actual data points for specific 주산지 weather data
    actual_data_points_specific = specific_subset['순 평균기온'].count()

    # If general data availability is below 50%, return NaNs for general features
    if actual_data_points_general / expected_data_points < 0.5:
        누적강수량, 평균기온 = np.nan, np.nan
    else:
        누적강수량 = general_subset['순 강수량'].sum(skipna=True)
        평균기온 = general_subset['순 평균기온'].mean(skipna=True)
    
    # If specific data availability is below 50%, return NaNs for 주산지-specific features
    if actual_data_points_specific / expected_data_points < 0.5:
        주산지_누적강수량, 주산지_평균기온 = np.nan, np.nan
    else:
        주산지_누적강수량 = specific_subset['순 강수량'].sum(skipna=True)
        주산지_평균기온 = specific_subset['순 평균기온'].mean(skipna=True)
    
    # Return all four calculated features as a Series
    return pd.Series({
        '순 강수량': 누적강수량,
        '순 평균기온': 평균기온,
        '주산지 순 강수량': 주산지_누적강수량,
        '주산지 순 평균기온': 주산지_평균기온
    })

# Apply the function and add results to cabbage_data
weather_features = cabbage_data.apply(calculate_weather_features, axis=1)
cabbage_data = pd.concat([cabbage_data, weather_features], axis=1)

# %%
cabbage_data

# %%
import matplotlib.pyplot as plt

# Plot 누적 강수량 vs 평균가격(원)

fig, ax1 = plt.subplots(figsize=(10, 6))

# 누적 강수량 on primary y-axis
ax1.plot(cabbage_data['date'], cabbage_data['순 강수량'], marker='o', color='blue', label='누적 강수량')
ax1.set_xlabel('Date')
ax1.set_ylabel('누적 강수량')
ax1.legend(loc='upper left')
ax1.grid(True)
ax1.tick_params(axis='x', rotation=45)

# 평균가격(원) on secondary y-axis
ax2 = ax1.twinx()
ax2.plot(cabbage_data['date'], cabbage_data['평균가격(원)'], marker='o', color='green', label='평균가격(원)')
ax2.set_ylabel('평균가격(원)')
ax2.legend(loc='upper right')

plt.title('누적 강수량 and 평균가격(원) Over Time')
plt.tight_layout()
plt.show()

# Plot 평균기온 vs 평균가격(원)
fig, ax1 = plt.subplots(figsize=(10, 6))

# 평균기온 on primary y-axis , scaled 된 수치임
ax1.plot(cabbage_data['date'], cabbage_data['순 평균기온'], marker='o', color='orange', label='평균기온')
ax1.set_xlabel('Date')
ax1.set_ylabel('평균기온')
ax1.legend(loc='upper left')
ax1.grid(True)
ax1.tick_params(axis='x', rotation=45)

# 평균가격(원) on secondary y-axis
ax2 = ax1.twinx()
ax2.plot(cabbage_data['date'], cabbage_data['평균가격(원)'], marker='o', color='green', label='평균가격(원)')
ax2.set_ylabel('평균가격(원)')
ax2.legend(loc='upper right')

plt.title('평균기온 and 평균가격(원) Over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# cabbage_data.columns

# %% [markdown]
# ## 단수

# %%
cabbage_data.columns
# Out:
# Index(['YYYYMMSOON', '가락시장 품목코드(5자리)', '품목(품종)명', '거래단위',
#        '등급(특 5% 상 35% 중 40% 하 20%)', '평균가격(원)', '전순 평균가격(원) PreVious SOON',
#        '전달 평균가격(원) PreVious MMonth', '전년 평균가격(원) PreVious YeaR',
#        '평년 평균가격(원) Common Year SOON', 'year', 'soon', 'date', '품목-품종', '품목명',
#        'original_month', 'original_day', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'day_1', 'day_11', 'day_21', '주산지',
#        '지역 이름', '순 강수량', '순 평균기온'],
#       dtype='object')

# %%
meta_production['단수'] = (meta_production['생산량(톤)'] * 10) / meta_production['재배면적(ha)']
meta_production['단수'].replace([np.inf, -np.inf], np.nan, inplace=True)
meta_production = meta_production.rename(columns={'년도': 'year', '품목명': '품목(품종)명'})
cabbage_data = pd.merge(cabbage_data, meta_production[['year', '품목(품종)명', '단수']], on=['year', '품목(품종)명'], how='left')

# %% [markdown]
# ## 총반입량

# %%
meta_nationwide_market = datetime_cov(meta_nationwide_market)

# %%
cabbage_data.columns
# Out:
# Index(['YYYYMMSOON', '가락시장 품목코드(5자리)', '품목(품종)명', '거래단위',
#        '등급(특 5% 상 35% 중 40% 하 20%)', '평균가격(원)', '전순 평균가격(원) PreVious SOON',
#        '전달 평균가격(원) PreVious MMonth', '전년 평균가격(원) PreVious YeaR',
#        '평년 평균가격(원) Common Year SOON', 'year', 'soon', 'date', '품목-품종', '품목명',
#        'original_month', 'original_day', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'day_1', 'day_11', 'day_21', '주산지',
#        '지역 이름', '순 강수량', '순 평균기온', '단수'],
#       dtype='object')

# %%
meta_nationwide_market.columns
# Out:
# Index(['YYYYMMSOON', '시장코드', '시장명', '품목코드', '품목명', '품종코드', '품종명', '총반입량(kg)',
#        '총거래금액(원)', '평균가(원/kg)', '고가(20%) 평균가', '중가(60%) 평균가 ', '저가(20%) 평균가',
#        '중간가(원/kg)', '최저가(원/kg)', '최고가(원/kg)', '경매 건수',
#        '전순 평균가격(원) PreVious SOON', '전달 평균가격(원) PreVious MMonth',
#        '전년 평균가격(원) PreVious YeaR', '평년 평균가격(원) Common Year SOON', '연도', 'year',
#        'month', 'soon', 'day', 'date'],
#       dtype='object')

# %%
meta_production.columns
# Out:
# Index(['year', '품목(품종)명', '재배면적(ha)', '생산량(톤)', '단수'], dtype='object')

# %%
total_import = meta_nationwide_market[meta_nationwide_market['품목명'] == '배추'].groupby(['year', 'month', 'date']).agg({'총반입량(kg)': 'sum'}).reset_index()
cabbage_data = pd.merge(cabbage_data, total_import, on=['year', 'date'], how='left', suffixes=('', '_total'))

cabbage_data = pd.merge(cabbage_data, meta_production[['year', '품목(품종)명', '생산량(톤)']], on=['year', '품목(품종)명'], how='left')

cabbage_data['반입량_생산량비'] = cabbage_data['총반입량(kg)_total'] / (cabbage_data['생산량(톤)'] * 1000)  
cabbage_data['반입량_생산량비'].replace([np.inf, -np.inf], np.nan, inplace=True)
