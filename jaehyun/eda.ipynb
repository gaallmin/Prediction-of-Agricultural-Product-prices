# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#plt.rcParams['font.family'] = 'Malgun Gothic'  # For Windows
plt.rcParams['font.family'] = 'Nanum Gothic'  # For macOS/Linux (you might need to install this font)

# Resolve minus sign display issue
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df = pd.read_csv('./dataset/train/train.csv')
print(df.head(20))
# Out:
#           시점  품목명 품종명   거래단위  등급     평년 평균가격(원)   평균가격(원)
# 0   201801상순  건고추  화건  30 kg  상품  381666.666667  590000.0
# 1   201801중순  건고추  화건  30 kg  상품  380809.666667  590000.0
# 2   201801하순  건고추  화건  30 kg  상품  380000.000000  590000.0
# 3   201802상순  건고추  화건  30 kg  상품  380000.000000  590000.0
# 4   201802중순  건고추  화건  30 kg  상품  376666.666667  590000.0
# 5   201802하순  건고추  화건  30 kg  상품  376666.666667  580833.0
# 6   201803상순  건고추  화건  30 kg  상품  376666.666667  563333.0
# 7   201803중순  건고추  화건  30 kg  상품  375208.333333  575000.0
# 8   201803하순  건고추  화건  30 kg  상품  372333.333333  575000.0
# 9   201804상순  건고추  화건  30 kg  상품  371000.000000  575000.0
# 10  201804중순  건고추  화건  30 kg  상품  368143.000000  575000.0
# 11  201804하순  건고추  화건  30 kg  상품  363762.000000  575000.0
# 12  201805상순  건고추  화건  30 kg  상품  361619.000000  575000.0
# 13  201805중순  건고추  화건  30 kg  상품  359333.333333  575000.0
# 14  201805하순  건고추  화건  30 kg  상품  359333.333333  575000.0
# ...

# %%
df_train1 = pd.read_csv('./dataset/train/meta/TRAIN_산지공판장_2018-2021.csv')
print(df_train1.head(20))
# Out:
#           시점       공판장코드      공판장명  품목코드 품목명   품종코드   품종명  등급코드 등급명  총반입량(kg)  \
# 0   201801상순  1000000000  *전국농협공판장   501  감자  50101    수미    11   특   15470.0
# 1   201801상순  1000000000  *전국농협공판장   501  감자  50101    수미    12   상    2900.0
# 2   201801상순  1000000000  *전국농협공판장   501  감자  50199  기타감자    13  보통    1320.0
# 3   201801상순  1000000000  *전국농협공판장   501  감자  50199  기타감자    12   상     460.0
# 4   201801상순  1000000000  *전국농협공판장   501  감자  50199  기타감자    11   특   30967.0
# 5   201801상순  1000000000  *전국농협공판장   501  감자  50199  기타감자    10   .    3973.0
# 6   201801상순  1000000000  *전국농협공판장   501  감자  50121  돼지감자    11   특     334.0
# 7   201801상순  1000000000  *전국농협공판장   501  감자  50121  돼지감자    10   .     146.0
# 8   201801상순  1000000000  *전국농협공판장   501  감자  50110  자주감자    13  보통      40.0
# 9   201801상순  1000000000  *전국농협공판장   501  감자  50110  자주감자    11   특     140.0
# 10  201801상순  1000000000  *전국농협공판장   501  감자  50101    수미    10   .   40930.0
# ...

# %%
print(df_train1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118628 entries, 0 to 118627
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   시점                           118628 non-null  object
#  1   공판장코드                        118628 non-null  int64
#  2   공판장명                         118628 non-null  object
#  3   품목코드                         118628 non-null  int64
#  4   품목명                          118628 non-null  object
#  5   품종코드                         118628 non-null  int64
#  6   품종명                          118628 non-null  object
#  7   등급코드                         118628 non-null  int64
#  8   등급명                          118628 non-null  object
#  9   총반입량(kg)                     118628 non-null  float64
#  10  총거래금액(원)                     118628 non-null  int64
#  11  평균가(원/kg)                    118628 non-null  float64
# ...

# %%
print(df_train1[df_train1['품목명'] == '배'])
# Out:
#               시점       공판장코드         공판장명  품목코드 품목명   품종코드 품종명  등급코드 등급명  \
# 52      201801상순  1000000000     *전국농협공판장   602   배  60201  신고    10   .
# 53      201801상순  1000000000     *전국농협공판장   602   배  60201  신고    11   특
# 54      201801상순  1000000000     *전국농협공판장   602   배  60201  신고    12   상
# 55      201801상순  1000000000     *전국농협공판장   602   배  60201  신고    13  보통
# 56      201801상순  1000000000     *전국농협공판장   602   배  60201  신고    15  5등
# ...          ...         ...          ...   ...  ..    ...  ..   ...  ..
# 118534  202112하순  6128201171  통영농협 농산물공판장   602   배  60201  신고    14  4등
# 118535  202112하순  6128201171  통영농협 농산물공판장   602   배  60201  신고    11   특
# 118536  202112하순  6128201171  통영농협 농산물공판장   602   배  60201  신고    12   상
# 118537  202112하순  6128201171  통영농협 농산물공판장   602   배  60201  신고    10   .
# 118581  202112하순  6168223255  제주시농협농산물공판장   602   배  60201  신고    11   특
#
#         총반입량(kg)  ...    평균가(원/kg)    중간가(원/kg)    최저가(원/kg)    최고가(원/kg)  \
# ...

# %%
df_train2 = pd.read_csv('./dataset/train/meta/TRAIN_전국도매_2018-2021.csv')
print(df_train2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176014 entries, 0 to 176013
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   시점                           176014 non-null  object
#  1   시장코드                         176014 non-null  int64
#  2   시장명                          176014 non-null  object
#  3   품목코드                         176014 non-null  int64
#  4   품목명                          176014 non-null  object
#  5   품종코드                         176014 non-null  int64
#  6   품종명                          176014 non-null  object
#  7   총반입량(kg)                     176014 non-null  float64
#  8   총거래금액(원)                     176014 non-null  int64
#  9   평균가(원/kg)                    176014 non-null  float64
#  10  고가(20%) 평균가                  176014 non-null  float64
#  11  중가(60%) 평균가                  176014 non-null  float64
# ...

# %%
print(df_train2.head(5))
# Out:
#          시점    시장코드      시장명  품목코드 품목명   품종코드   품종명   총반입량(kg)    총거래금액(원)  \
# 0  201801상순  100000  *전국도매시장   501  감자  50124   깐감자       20.0       86520
# 1  201801상순  100000  *전국도매시장   501  감자  50121  돼지감자    12380.0    11650810
# 2  201801상순  100000  *전국도매시장   501  감자  50110  자주감자      240.0      158400
# 3  201801상순  100000  *전국도매시장   501  감자  50111  가을감자       10.0       37500
# 4  201801상순  100000  *전국도매시장   501  감자  50199  기타감자  1367301.3  2403199462
#
#      평균가(원/kg)  ...  저가(20%) 평균가    중간가(원/kg)  최저가(원/kg)     최고가(원/kg)  경매 건수  \
# 0  4326.000000  ...  4326.000000  4326.000000     4326.0   4326.000000      1
# 1   941.099354  ...   545.105717  1010.000000      200.0   3000.000000    117
# 2   660.000000  ...   500.000000   550.000000      500.0   1000.000000      7
# 3  3750.000000  ...  3700.000000  3750.000000     3700.0   3800.000000      2
# 4  1757.622451  ...   955.289668  1360.453431        0.0  10581.081081    872
#
# ...

# %%
print('main data',df.isnull().sum())
print('meta1',df_train1.isnull().sum())
print('meta2',df_train2.isnull().sum())
# Out:
# main data 시점            0
# 품목명           0
# 품종명           0
# 거래단위          0
# 등급            0
# 평년 평균가격(원)    0
# 평균가격(원)       0
# dtype: int64
# meta1 시점                             0
# 공판장코드                          0
# 공판장명                           0
# 품목코드                           0
# 품목명                            0
# 품종코드                           0
# 품종명                            0
# 등급코드                           0
# 등급명                            0
# 총반입량(kg)                       0
# 총거래금액(원)                       0
# 평균가(원/kg)                      0
# 중간가(원/kg)                      0
# 최저가(원/kg)                      0
# 최고가(원/kg)                      0
# 경매 건수                          0
# 전순 평균가격(원) PreVious SOON       0
# 전달 평균가격(원) PreVious MMonth     0
# 전년 평균가격(원) PreVious YeaR       0
# 평년 평균가격(원) Common Year SOON    0
# 연도                             0
# dtype: int64
# meta2 시점                             0
# 시장코드                           0
# ...

# %% [markdown]
# ## meta data
# might be used for
# 1) enhancing feature set
# - Location based : we can include region-specific economic indicators, climate factors
# - market specific : market size ~ num of transaction (반입량) = understand supply- demand dynamics
#
# 2) Aggregating meta d by different levels (montly / quartely)
#
# 3) Understand seansol effect

# %%
print(df.info())
print(df_train1.info())
print(df_train2.info())
# 품목명, 품종명 same
# df 등급 : by 상품 or not
# meta 등급: by num
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29376 entries, 0 to 29375
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시점          29376 non-null  object
#  1   품목명         29376 non-null  object
#  2   품종명         29376 non-null  object
#  3   거래단위        29376 non-null  object
#  4   등급          29376 non-null  object
#  5   평년 평균가격(원)  29376 non-null  float64
#  6   평균가격(원)     29376 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 1.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118628 entries, 0 to 118627
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   시점                           118628 non-null  object
#  1   공판장코드                        118628 non-null  int64
#  2   공판장명                         118628 non-null  object
# ...

# %%
print(df['등급'].describe())
print(df['등급'].unique())
# Out:
# count     29376
# unique        6
# top           상
# freq       7056
# Name: 등급, dtype: object
# ['상품' '중품' '상' '특' '하' '중']

# %%
print(df_train1['등급명'].describe())
print(df_train1['등급명'].unique())

#전국 도매는 등급명 없음
# Out:
# count     118628
# unique        10
# top            특
# freq       43071
# Name: 등급명, dtype: object
# ['특' '상' '보통' '.' '등외' '4등' '5등' '6등' '7등' '8등']

# %% [markdown]
# Ensure Consistent Date Formats:
#
# Convert the 시점 column to datetime objects in all datasets to ensure consistency.
# Check for Unique Combinations:
#
# Verify if the combination of 시점, 품목명, and 품종명 uniquely identifies records in the meta data. If not, aggregation may be needed.
# Merge Datasets:
#
# Merge the main dataset with each meta data file using 시점, 품목명, and 품종명 as keys.
# Handle Aggregations:
#
# If multiple entries exist for the same 시점, 품목명, and 품종명, aggregate the meta data (e.g., sum, mean) before merging.

# %% [markdown]
# ## Data Cleaning

# %%
# parsing 시점 column 
# 하순 : 5th, 중순: 15th, 상순: 25th
def parse_date(date):
    year = int(date[:4])
    month = int(date[4:6])
    period = date[6:]

    if period == '하순':
        day = 5
    elif period == '중순':
        day = 15
    elif period == '상순':
        day = 25
    else:
        day = 1
        
    return pd.Timestamp(year=year, month=month, day=day)

df['datetime'] = df['시점'].apply(parse_date)
df_train1['datetime'] = df_train1['시점'].apply(parse_date)
df_train2['datetime'] = df_train2['시점'].apply(parse_date)

df.set_index('datetime', inplace=True)
df_train1.set_index('datetime', inplace=True)
df_train2.set_index('datetime', inplace=True)

print(df.head())
# Out:
#                   시점  품목명 품종명   거래단위  등급     평년 평균가격(원)   평균가격(원)
# datetime
# 2018-01-25  201801상순  건고추  화건  30 kg  상품  381666.666667  590000.0
# 2018-01-15  201801중순  건고추  화건  30 kg  상품  380809.666667  590000.0
# 2018-01-05  201801하순  건고추  화건  30 kg  상품  380000.000000  590000.0
# 2018-02-25  201802상순  건고추  화건  30 kg  상품  380000.000000  590000.0
# 2018-02-15  201802중순  건고추  화건  30 kg  상품  376666.666667  590000.0

# %%
# standardizing 거래단위
df['거래단위'] = df['거래단위'].str.replace(' ','')
print(df['거래단위'].unique())
# Out:
# ['30kg' '10개' '20키로상자' '10키로상자' '23키로상자' '20kg' '10키로' '18키로상자(비닐포)'
#  '5000키로' '5톤트럭' '1000키로' '4키로상자' '1.5키로단' '8톤트럭' '100g' '10키로망대' '1키로상자'
#  '8키로상자' '15키로상자' '1키로' '15키로' '12키로' '20키로' '1키로단' '10키로묶음']

# %%
# # filtering by the requirment
# target_items = [
#     {'품목명': '건고추', '품종명': '화건', '거래단위': '30kg', '등급': '상품'},
#     {'품목명': '사과', '품종명': '홍로', '거래단위': '10개', '등급': '상품'},
#     {'품목명': '사과', '품종명': '후지', '거래단위': '10개', '등급': '상품'},
#     {'품목명': '감자', '품종명': '감자수미', '거래단위': '20kg상자', '등급': '상품'},
#     {'품목명': '배', '품종명': '신고', '거래단위': '10개', '등급': '상품'},
#     {'품목명': '깐마늘', '품종명': '국산', '거래단위': '20kg', '등급': '상품'},
#     {'품목명': '무', '품종명': '무', '거래단위': '20kg상자', '등급': '상품'},
#     {'품목명': '상추', '품종명': '청', '거래단위': '100g', '등급': '상품'},
#     {'품목명': '배추', '품종명': '배추', '거래단위': '10kg망대', '등급': '상품'},
#     {'품목명': '양파', '품종명': '양파', '거래단위': '1kg', '등급': '상품'},
#     {'품목명': '대파', '품종명': '대파', '거래단위': '1kg단', '등급': '상품'},
# ]

# target_df = pd.DataFrame(target_items)

# %%
# how to deal with different unit (kg, 개 etc)

# %% [markdown]
# how to use meta data is important, how to definethe data
#
# on meta data everything is mesaured based on 1kg

# %% [markdown]
# # EDA

# %% [markdown]
# ### Key Focus Areas for EDA and Modeling
# 1. Time Series Characteristics:
# - Trends: Identify overall direction in the data (upward/downward).
# - Seasonality: Detect repeating patterns at regular intervals (monthly, yearly).
# - Stationarity: Ensure the series has constant mean and variance over time.
#
# 2. Meta Data Utilization:
# - Transaction Volume and Amount: Understand how transaction metrics correlate with prices.
# - Auction Counts: Explore the impact of auctions on price fluctuations.
# - Previous Period Prices: Utilize lagged price information from meta data.
#
# 3. Feature Relationships:
# - Correlation Analysis: Determine which features are most strongly associated with the target.
# - Interaction Effects: Examine how combinations of features affect prices.
#
# 4. Handling Categorical Variables:
# - Encoding Techniques: Use One-Hot Encoding for tree-based models.
# - Consistency: Ensure consistent encoding across training and test datasets.
#
# 5. Temporal Integrity:
# - Avoid Data Leakage: Ensure that no future information is used to predict past or current prices.
# - Validation Strategy: Use time-based splits like TimeSeriesSplit to maintain the sequence.

# %%
print(df['품목명'].unique())
print(df['품종명'].unique())
# Out:
# ['건고추' '사과' '감자' '배' '깐마늘(국산)' '무' '상추' '배추' '양파' '대파']
# ['화건' '햇산양건' '햇산화건' '양건' '후지' '홍로' '쓰가루' '감자 수미' '감자 수미(햇)' '감자' '감자 조풍'
#  '감자 대지' '감자 두백' '감자 수미(저장)' '홍감자' '감자 수입' '신고' '원황' '깐마늘(국산)' '무' '다발무'
#  '열무' '청' '적' '배추' '쌈배추' '알배기배추' '얼갈이배추' '봄동배추' '절임배추' '양파' '저장양파' '조생양파'
#  '양파(햇)' '자주양파' '양파 수입' '대파(일반)' '실파' '깐쪽파' '쪽파' '대파 수입']

# %%
# categorical var : frequency
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='품목명')
plt.title('Distribution of Product Names')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12,6))
sns.countplot(data=df, x='품종명')
plt.title('Distribution of Variety Names')
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(12,6))
sns.countplot(data=df, x='등급')
plt.title('Distribution of Grades')
plt.xticks(rotation=45)
plt.show()
# Out:
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt

# Filter data for '배' and plot the price trend over time
plt.plot(df['시점'], df['평균가격(원)'], marker='o')
plt.title('Price Trend')
plt.xlabel('시점')
plt.ylabel('평균가격(원)')
plt.xticks(rotation=45)
plt.show()
# Out:
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Group the data by '품목명' and '품종명' and calculate the mean price for each group
grouped_data = df.groupby(['품목명', '품종명', '시점'])['평균가격(원)'].mean().reset_index()

# Check the head of the grouped data
print(grouped_data.head())
# Out:
#   품목명 품종명        시점  평균가격(원)
# 0  감자  감자  201801상순      0.0
# 1  감자  감자  201801중순      0.0
# 2  감자  감자  201801하순      0.0
# 3  감자  감자  201802상순      0.0
# 4  감자  감자  201802중순      0.0

# %%
import matplotlib.pyplot as plt

# Function to plot trend for each 품목 and 품종
def plot_trend_by_product_variety(df, product_name):
    # Filter data for the selected product
    product_data = df[df['품목명'] == product_name]

    # Get the unique 품종명 (varieties) for the selected 품목
    varieties = product_data['품종명'].unique()

    # Plot price trend for each 품종
    plt.figure(figsize=(10, 6))
    for variety in varieties:
        variety_data = product_data[product_data['품종명'] == variety]
        plt.plot(variety_data['시점'], variety_data['평균가격(원)'], label=variety)
        
        print(variety_data.keys())

    plt.title(f'Price Trend for 품목: {product_name}')
    plt.xlabel('시점')
    plt.ylabel('평균가격(원)')
    plt.xticks(rotation=45)
    plt.legend(title='품종명')
    plt.show()

# Example: Plot trend for a specific 품목 ('건고추' in this case)
plot_trend_by_product_variety(grouped_data, '건고추')
# Out:
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Group the data by '품목명' and '품종명' and calculate the mean price for each group
grouped_data = df.groupby(['품목명', '품종명', '시점'])['평년 평균가격(원)'].mean().reset_index()

# Check the head of the grouped data
print(grouped_data.head())
# Out:
#   품목명 품종명        시점  평년 평균가격(원)
# 0  감자  감자  201801상순         0.0
# 1  감자  감자  201801중순         0.0
# 2  감자  감자  201801하순         0.0
# 3  감자  감자  201802상순         0.0
# 4  감자  감자  201802중순         0.0

# %%
import matplotlib.pyplot as plt

# Function to plot trend for each 품목 and 품종
def plot_trend_by_product_variety(df, product_name):
    # Filter data for the selected product
    product_data = df[df['품목명'] == product_name]

    # Get the unique 품종명 (varieties) for the selected 품목
    varieties = product_data['품종명'].unique()

    # Plot price trend for each 품종
    plt.figure(figsize=(10, 6))
    for variety in varieties:
        variety_data = product_data[product_data['품종명'] == variety]
        plt.plot(variety_data['시점'], variety_data['평년 평균가격(원)'], label=variety)
        
        print(variety_data.keys())

    plt.title(f'Price Trend for 품목: {product_name}')
    plt.xlabel('시점')
    plt.ylabel('평균가격(원)')
    plt.xticks(rotation=45)
    plt.legend(title='품종명')
    plt.show()

# Example: Plot trend for a specific 품목 ('건고추' in this case)
plot_trend_by_product_variety(grouped_data, '건고추')
# Out:
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# findfont: Font family 'Nanum Gothic' not found.
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.venv/PoAP/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
